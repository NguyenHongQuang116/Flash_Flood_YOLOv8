# %% [markdown]
# # This is a notebook for training the YOLOv8 model for Flash Flood detection and model deploying for photos, videos, and live webcam applications.
# ## Prof. Gihong Kim's Lab
# ### Department of Civil and Environmental Engineering, Gangneung-Wonju National University; Engineering Building No. 2, 7, Jukheon-gil, Gangneung-si, Gangwon-do 25457, Korea: Email: ghkim@gwnu.ac.kr

# %% [markdown]
# # Check the GPU is properly installed!

# %%
import torch
print (torch.cuda.device_count())
print (torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Import YOLO model from the Ultralytics library

# %%
from ultralytics import YOLO

# %% [markdown]
# ## import the YOLOv8 (including n, s, m, L, x)

# %%
# Load a model
model = YOLO("yolov8x.yaml")  # build a new model from scratch
#model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
# ...

# %% [markdown]
# ## Train the YOLO, with defferent epoch number (25, 50, 75, 100...)

# %%
# Use the model
results = model.train(data="config.yaml", epochs=100)  # train the model
#metrics = model.val()  # evaluate model performance on the validation set
#results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
#path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# New https://pypi.org/project/ultralytics/8.1.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.2 🚀 Python-3.11.5 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %% [markdown]
# ## Model validation (using test dataset)

# %%
metrics = model.val(data="config.yaml", epochs=100)  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.11.5 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv8x summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\user\anaconda3\envs\gpuEnv\yoloV8\data\labels\val.cache... 54 images, 0 backgrounds, 0 corrupt: 100%|██████████| 54/54 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:03<00:00,  1.14it/s]
#                    all         54         54      0.719      0.615      0.711      0.308
# Speed: 0.2ms preprocess, 12.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs\detect\train132

# %% [markdown]
# ## Export model result in defferent modes (single image, video, and real-time PC camera

# %%
#==============================================================================
from ultralytics import YOLO
from ultralytics.models.yolo.detect.predict import DetectionPredictor
import cv2

model = YOLO("C:/Users/user/anaconda3/envs/gpuEnv/yoloV8/runs/detect/train9222/weights/best.pt") # import decoding model
#model.predict(source="D:\DATA\YOLOV8\Flash_flood_CCTV\KBS\KBS_0711.mp4", show=True, save = True, conf= 0.3) # test with a video
#result= model.predict(source="C:/Users/user/anaconda3/envs/gpuEnv/yoloV8/data/images/test/Test_FF_Korea124.JPG", show=True, conf= 0.3) # Predict an image of flash flood
model.predict(source=0, show=True, conf= 0.3) # predict FF using PC camera
result
save = True
cv2.destroyAllWindows()
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 flash_flood, 325.3ms
# 0: 480x640 1 flash_flood, 7.0ms
# 0: 480x640 1 flash_flood, 6.0ms
# 0: 480x640 1 flash_flood, 6.4ms
# 0: 480x640 1 flash_flood, 6.0ms
# 0: 480x640 1 flash_flood, 7.0ms
# 0: 480x640 1 flash_flood, 7.1ms
# 0: 480x640 1 flash_flood, 7.0ms
# 0: 480x640 1 flash_flood, 7.0ms
# 0: 480x640 1 flash_flood, 6.0ms
# ...
